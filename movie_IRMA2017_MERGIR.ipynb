# %% [markdown]
# # Loop over MERGEDIR satellite datafiles, making images

# %%
# !pip install xarray matplotlib cartopy xemsf netCDF4

# %%
import xarray as xr
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import numpy as np
from pathlib import Path
import os
from subprocess import run

# ==== USER CONFIG ====
data_folder = Path("/Users/bmapes/Box/Sky_Symphony_Box/IRMA2017/MERGEDIR_BOXES/")  # change this
frame_folder =Path("/Users/bmapes/Box/Sky_Symphony_Box/IRMA2017/MERGEDIR_BOXES/frames")
frame_folder.mkdir(exist_ok=True)
video_filename = "/Users/bmapes/Box/Sky_Symphony_Box/IRMA2017/MERGEDIR_BOXES/"+"enhanced_ir.mp4"

vmin, vmax = 170, 300
dpi = 150
# =====================

frame_folder.mkdir(exist_ok=True)

# 1. Create enhanced IR colormap (cold to warm)
def create_enhanced_ir_colormap():

    color_points = [
        (170, "#000000"),  # black (coldest cloud tops)
        (180, "#800080"),  # purple
        (190, "#ff0000"),  # red
        (200, "#ff8000"),  # orange
        (210, "#ffff00"),  # yellow
        (220, "#00ff00"),  # green
        (235, "#00ffff"),  # cyan
        (240, "#0000ff"),  # blue (end of enhancement)
        (250, "#ffffff"),  # white (warmest)
        (270, "#dcdcdc"),  # light gray
        (285, "#a0a0a0"),  # mid gray
        (300, "#000000"),  # black surface

    ]
    temps, colors = zip(*color_points)
    normed = [(t - min(temps)) / (max(temps) - min(temps)) for t in temps]
    normed[0], normed[-1] = 0.0, 1.0
    return mcolors.LinearSegmentedColormap.from_list("enhanced_ir", list(zip(normed, colors)), N=256)

cmap = create_enhanced_ir_colormap()
norm = mcolors.Normalize(vmin=vmin, vmax=vmax)

# 2. Preload lat/lon grids from all files
nc_files = sorted(data_folder.glob("*.nc"))
grid_info = []
for file in nc_files:
    with xr.open_dataset(file) as ds:
        grid_info.append({
            "file": file,
            "lat": ds['lat'].load(),
            "lon": ds['lon'].load()
        })

# 3. Generate plots with smoothed coastline movement
frame_count = 0

for i, grid in enumerate(grid_info):
    ds = xr.open_dataset(grid['file'])
    Tb_all = ds['Tb']
    lat_now = grid['lat']
    lon_now = grid['lon']

    if i < len(grid_info) - 1:
        lat_next = grid_info[i+1]['lat']
        lon_next = grid_info[i+1]['lon']
    else:
        lat_next = lat_now
        lon_next = lon_now

    for t in range(Tb_all.sizes['time']):
        Tb = Tb_all.isel(time=t)
        timestamp = str(Tb_all.time.values[t])[:16].replace(":", "").replace("T", "_")

        # Smooth coastlines for 2nd timestep
        if t == 0:
            coast_lat = lat_now
            coast_lon = lon_now
        else:
            coast_lat = 0.5 * (lat_now + lat_next)
            coast_lon = 0.5 * (lon_now + lon_next)

        # Define extent from coast grid
        extent = [
            float(coast_lon.min()), float(coast_lon.max()),
            float(coast_lat.min()), float(coast_lat.max())
        ]

        # Plot
        fig, ax = plt.subplots(figsize=(10, 6), subplot_kw={'projection': ccrs.PlateCarree()})
        Tb.plot.imshow(
            ax=ax,
            transform=ccrs.PlateCarree(),
            cmap=cmap,
            norm=norm,
            add_colorbar=True,
            cbar_kwargs={'label': 'Brightness Temperature [K]'}
        )

        ax.set_extent(extent, crs=ccrs.PlateCarree())
        ax.coastlines()
        ax.add_feature(cfeature.BORDERS, linewidth=0.5)
        ax.set_title(f"Tb at {timestamp}", fontsize=12)
        plt.tight_layout()

        out_file = frame_folder / f"frame_{frame_count:04d}.png"
        plt.savefig(out_file, dpi=dpi)
        plt.close()
        print(f"Saved {out_file.name}")
        frame_count += 1

# 4. Create video using ffmpeg
ffmpeg_cmd = [
    "ffmpeg", "-y", "-framerate", "6",
    "-i", str(frame_folder / "frame_%04d.png"),
    "-c:v", "libx264", "-pix_fmt", "yuv420p",
    video_filename
]

print("Creating video...")
run(ffmpeg_cmd)
print(f"✅ Video saved as {video_filename}")
# Out:
# Saved frame_0000.png
# Saved frame_0001.png
# Saved frame_0002.png
# Saved frame_0003.png
# Saved frame_0004.png
# Saved frame_0005.png
# Saved frame_0006.png
# Saved frame_0007.png
# Saved frame_0008.png
# Saved frame_0009.png
# Saved frame_0010.png
# Saved frame_0011.png
# Saved frame_0012.png
# Saved frame_0013.png
# Saved frame_0014.png
# Saved frame_0015.png
# Saved frame_0016.png
# Saved frame_0017.png
# Saved frame_0018.png
# Saved frame_0019.png
# Saved frame_0020.png
# Saved frame_0021.png
# Saved frame_0022.png
# Saved frame_0023.png
# Saved frame_0024.png
# Saved frame_0025.png
# Saved frame_0026.png
# Saved frame_0027.png
# Saved frame_0028.png
# Saved frame_0029.png
# Saved frame_0030.png
# Saved frame_0031.png
# Saved frame_0032.png
# Saved frame_0033.png
# Saved frame_0034.png
# Saved frame_0035.png
# Saved frame_0036.png
# Saved frame_0037.png
# Saved frame_0038.png
# Saved frame_0039.png
# Saved frame_0040.png
# Saved frame_0041.png
# Saved frame_0042.png
# Saved frame_0043.png
# Saved frame_0044.png
# Saved frame_0045.png
# Saved frame_0046.png
# Saved frame_0047.png
# Saved frame_0048.png
# Saved frame_0049.png
# Saved frame_0050.png
# Saved frame_0051.png
# Saved frame_0052.png
# Saved frame_0053.png
# Saved frame_0054.png
# Saved frame_0055.png
# Saved frame_0056.png
# Saved frame_0057.png
# Saved frame_0058.png
# Saved frame_0059.png
# Saved frame_0060.png
# Saved frame_0061.png
# Saved frame_0062.png
# Saved frame_0063.png
# Saved frame_0064.png
# Saved frame_0065.png
# Saved frame_0066.png
# Saved frame_0067.png
# Saved frame_0068.png
# Saved frame_0069.png
# Saved frame_0070.png
# Saved frame_0071.png
# Saved frame_0072.png
# Saved frame_0073.png
# Saved frame_0074.png
# Saved frame_0075.png
# Saved frame_0076.png
# Saved frame_0077.png
# Saved frame_0078.png
# Saved frame_0079.png
# Saved frame_0080.png
# Saved frame_0081.png
# Saved frame_0082.png
# Saved frame_0083.png
# Saved frame_0084.png
# Saved frame_0085.png
# Saved frame_0086.png
# Saved frame_0087.png
# Saved frame_0088.png
# Saved frame_0089.png
# Saved frame_0090.png
# Saved frame_0091.png
# Saved frame_0092.png
# Saved frame_0093.png
# Saved frame_0094.png
# Saved frame_0095.png
# Saved frame_0096.png
# Saved frame_0097.png
# Saved frame_0098.png
# Saved frame_0099.png
# Saved frame_0100.png
# Saved frame_0101.png
# Saved frame_0102.png
# Saved frame_0103.png
# Saved frame_0104.png
# Saved frame_0105.png
# Saved frame_0106.png
# Saved frame_0107.png
# Saved frame_0108.png
# Saved frame_0109.png
# Saved frame_0110.png
# Saved frame_0111.png
# Saved frame_0112.png
# Saved frame_0113.png
# Saved frame_0114.png
# Saved frame_0115.png
# Saved frame_0116.png
# Saved frame_0117.png
# Saved frame_0118.png
# Saved frame_0119.png
# Saved frame_0120.png
# Saved frame_0121.png
# Saved frame_0122.png
# Saved frame_0123.png
# Saved frame_0124.png
# Saved frame_0125.png
# Saved frame_0126.png
# Saved frame_0127.png
# Saved frame_0128.png
# Saved frame_0129.png
# Saved frame_0130.png
# Saved frame_0131.png
# Saved frame_0132.png
# Saved frame_0133.png
# Saved frame_0134.png
# Saved frame_0135.png
# Saved frame_0136.png
# Saved frame_0137.png
# Saved frame_0138.png
# Saved frame_0139.png
# Saved frame_0140.png
# Saved frame_0141.png
# Saved frame_0142.png
# Saved frame_0143.png
# Saved frame_0144.png
# Saved frame_0145.png
# Saved frame_0146.png
# Saved frame_0147.png
# Saved frame_0148.png
# Saved frame_0149.png
# Saved frame_0150.png
# Saved frame_0151.png
# Saved frame_0152.png
# Saved frame_0153.png
# Saved frame_0154.png
# Saved frame_0155.png
# Saved frame_0156.png
# Saved frame_0157.png
# Saved frame_0158.png
# Saved frame_0159.png
# Saved frame_0160.png
# Saved frame_0161.png
# Saved frame_0162.png
# Saved frame_0163.png
# Saved frame_0164.png
# Saved frame_0165.png
# Saved frame_0166.png
# Saved frame_0167.png
# Saved frame_0168.png
# Saved frame_0169.png
# Saved frame_0170.png
# Saved frame_0171.png
# Saved frame_0172.png
# Saved frame_0173.png
# Saved frame_0174.png
# Saved frame_0175.png
# Saved frame_0176.png
# Saved frame_0177.png
# Saved frame_0178.png
# Saved frame_0179.png
# Saved frame_0180.png
# Saved frame_0181.png
# Saved frame_0182.png
# Saved frame_0183.png
# Saved frame_0184.png
# Saved frame_0185.png
# Saved frame_0186.png
# Saved frame_0187.png
# Saved frame_0188.png
# Saved frame_0189.png
# Saved frame_0190.png
# Saved frame_0191.png
# Saved frame_0192.png
# Saved frame_0193.png
# Saved frame_0194.png
# Saved frame_0195.png
# Saved frame_0196.png
# Saved frame_0197.png
# Saved frame_0198.png
# Saved frame_0199.png
# Saved frame_0200.png
# Saved frame_0201.png
# Saved frame_0202.png
# Saved frame_0203.png
# Saved frame_0204.png
# Saved frame_0205.png
# Saved frame_0206.png
# Saved frame_0207.png
# Saved frame_0208.png
# Saved frame_0209.png
# Saved frame_0210.png
# Saved frame_0211.png
# Saved frame_0212.png
# Saved frame_0213.png
# Saved frame_0214.png
# Saved frame_0215.png
# Saved frame_0216.png
# Saved frame_0217.png
# Saved frame_0218.png
# Saved frame_0219.png
# Saved frame_0220.png
# Saved frame_0221.png
# Saved frame_0222.png
# Saved frame_0223.png
# Saved frame_0224.png
# Saved frame_0225.png
# Saved frame_0226.png
# Saved frame_0227.png
# Saved frame_0228.png
# Saved frame_0229.png
# Saved frame_0230.png
# Saved frame_0231.png
# Saved frame_0232.png
# Saved frame_0233.png
# Saved frame_0234.png
# Saved frame_0235.png
# Saved frame_0236.png
# Saved frame_0237.png
# Saved frame_0238.png
# Saved frame_0239.png
# Saved frame_0240.png
# Saved frame_0241.png
# Saved frame_0242.png
# Saved frame_0243.png
# Saved frame_0244.png
# Saved frame_0245.png
# Saved frame_0246.png
# Saved frame_0247.png
# Saved frame_0248.png
# Saved frame_0249.png
# Saved frame_0250.png
# Saved frame_0251.png
# Saved frame_0252.png
# Saved frame_0253.png
# Saved frame_0254.png
# Saved frame_0255.png
# Saved frame_0256.png
# Saved frame_0257.png
# Saved frame_0258.png
# Saved frame_0259.png
# Saved frame_0260.png
# Saved frame_0261.png
# Saved frame_0262.png
# Saved frame_0263.png
# Saved frame_0264.png
# Saved frame_0265.png
# Saved frame_0266.png
# Saved frame_0267.png
# Saved frame_0268.png
# Saved frame_0269.png
# Saved frame_0270.png
# Saved frame_0271.png
# Saved frame_0272.png
# Saved frame_0273.png
# Saved frame_0274.png
# Saved frame_0275.png
# Saved frame_0276.png
# Saved frame_0277.png
# Saved frame_0278.png
# Saved frame_0279.png
# Saved frame_0280.png
# Saved frame_0281.png
# Saved frame_0282.png
# Saved frame_0283.png
# Saved frame_0284.png
# Saved frame_0285.png
# Saved frame_0286.png
# Saved frame_0287.png
# Saved frame_0288.png
# Saved frame_0289.png
# Saved frame_0290.png
# Saved frame_0291.png
# Saved frame_0292.png
# Saved frame_0293.png
# Saved frame_0294.png
# Saved frame_0295.png
# Saved frame_0296.png
# Saved frame_0297.png
# Saved frame_0298.png
# Saved frame_0299.png
# Saved frame_0300.png
# Saved frame_0301.png
# Saved frame_0302.png
# Saved frame_0303.png
# Saved frame_0304.png
# Saved frame_0305.png
# Saved frame_0306.png
# Saved frame_0307.png
# Saved frame_0308.png
# Saved frame_0309.png
# Saved frame_0310.png
# Saved frame_0311.png
# Saved frame_0312.png
# Saved frame_0313.png
# Saved frame_0314.png
# Saved frame_0315.png
# Saved frame_0316.png
# Saved frame_0317.png
# Saved frame_0318.png
# Saved frame_0319.png
# Saved frame_0320.png
# Saved frame_0321.png
# Saved frame_0322.png
# Saved frame_0323.png
# Saved frame_0324.png
# Saved frame_0325.png
# Saved frame_0326.png
# Saved frame_0327.png
# Saved frame_0328.png
# Saved frame_0329.png
# Saved frame_0330.png
# Saved frame_0331.png
# Saved frame_0332.png
# Saved frame_0333.png
# Saved frame_0334.png
# Saved frame_0335.png
# Saved frame_0336.png
# Saved frame_0337.png
# Saved frame_0338.png
# Saved frame_0339.png
# Saved frame_0340.png
# Saved frame_0341.png
# Saved frame_0342.png
# Saved frame_0343.png
# Saved frame_0344.png
# Saved frame_0345.png
# Saved frame_0346.png
# Saved frame_0347.png
# Saved frame_0348.png
# Saved frame_0349.png
# Saved frame_0350.png
# Saved frame_0351.png
# Saved frame_0352.png
# Saved frame_0353.png
# Saved frame_0354.png
# Saved frame_0355.png
# Saved frame_0356.png
# Saved frame_0357.png
# Saved frame_0358.png
# Saved frame_0359.png
# Saved frame_0360.png
# Saved frame_0361.png
# Saved frame_0362.png
# Saved frame_0363.png
# Saved frame_0364.png
# Saved frame_0365.png
# Saved frame_0366.png
# Saved frame_0367.png
# Saved frame_0368.png
# Saved frame_0369.png
# Saved frame_0370.png
# Saved frame_0371.png
# Saved frame_0372.png
# Saved frame_0373.png
# Saved frame_0374.png
# Saved frame_0375.png
# Saved frame_0376.png
# Saved frame_0377.png
# Saved frame_0378.png
# Saved frame_0379.png
# Saved frame_0380.png
# Saved frame_0381.png
# Saved frame_0382.png
# Saved frame_0383.png
# Saved frame_0384.png
# Saved frame_0385.png
# Saved frame_0386.png
# Saved frame_0387.png
# Saved frame_0388.png
# Saved frame_0389.png
# Saved frame_0390.png
# Saved frame_0391.png
# Saved frame_0392.png
# Saved frame_0393.png
# Saved frame_0394.png
# Saved frame_0395.png
# Saved frame_0396.png
# Saved frame_0397.png
# Saved frame_0398.png
# Saved frame_0399.png
# Saved frame_0400.png
# Saved frame_0401.png
# Saved frame_0402.png
# Saved frame_0403.png
# Saved frame_0404.png
# Saved frame_0405.png
# Saved frame_0406.png
# Saved frame_0407.png
# Saved frame_0408.png
# Saved frame_0409.png
# Saved frame_0410.png
# Saved frame_0411.png
# Saved frame_0412.png
# Saved frame_0413.png
# Saved frame_0414.png
# Saved frame_0415.png
# Saved frame_0416.png
# Saved frame_0417.png
# Saved frame_0418.png
# Saved frame_0419.png
# Saved frame_0420.png
# Saved frame_0421.png
# Saved frame_0422.png
# Saved frame_0423.png
# Saved frame_0424.png
# Saved frame_0425.png
# Saved frame_0426.png
# Saved frame_0427.png
# Saved frame_0428.png
# Saved frame_0429.png
# Saved frame_0430.png
# Saved frame_0431.png
# Saved frame_0432.png
# Saved frame_0433.png
# Saved frame_0434.png
# Saved frame_0435.png
# Saved frame_0436.png
# Saved frame_0437.png
# Saved frame_0438.png
# Saved frame_0439.png
# Saved frame_0440.png
# Saved frame_0441.png
# Saved frame_0442.png
# Saved frame_0443.png
# Saved frame_0444.png
# Saved frame_0445.png
# Saved frame_0446.png
# Saved frame_0447.png
# Saved frame_0448.png
# Saved frame_0449.png
# Saved frame_0450.png
# Saved frame_0451.png
# Saved frame_0452.png
# Saved frame_0453.png
# Saved frame_0454.png
# Saved frame_0455.png
# Saved frame_0456.png
# Saved frame_0457.png
# Saved frame_0458.png
# Saved frame_0459.png
# Saved frame_0460.png
# Saved frame_0461.png
# Saved frame_0462.png
# Saved frame_0463.png
# Saved frame_0464.png
# Saved frame_0465.png
# Saved frame_0466.png
# Saved frame_0467.png
# Saved frame_0468.png
# Saved frame_0469.png
# Saved frame_0470.png
# Saved frame_0471.png
# Saved frame_0472.png
# Saved frame_0473.png
# Saved frame_0474.png
# Saved frame_0475.png
# Saved frame_0476.png
# Saved frame_0477.png
# Saved frame_0478.png
# Saved frame_0479.png
# Saved frame_0480.png
# Saved frame_0481.png
# Saved frame_0482.png
# Saved frame_0483.png
# Saved frame_0484.png
# Saved frame_0485.png
# Saved frame_0486.png
# Saved frame_0487.png
# Saved frame_0488.png
# Saved frame_0489.png
# Saved frame_0490.png
# Saved frame_0491.png
# Saved frame_0492.png
# Saved frame_0493.png
# Saved frame_0494.png
# Saved frame_0495.png
# Saved frame_0496.png
# Saved frame_0497.png
# Saved frame_0498.png
# Saved frame_0499.png
# Saved frame_0500.png
# Saved frame_0501.png
# Saved frame_0502.png
# Saved frame_0503.png
# Saved frame_0504.png
# Saved frame_0505.png
# Saved frame_0506.png
# Saved frame_0507.png
# Saved frame_0508.png
# Saved frame_0509.png
# Saved frame_0510.png
# Saved frame_0511.png
# Saved frame_0512.png
# Saved frame_0513.png
# Saved frame_0514.png
# Saved frame_0515.png
# Saved frame_0516.png
# Saved frame_0517.png
# Saved frame_0518.png
# Saved frame_0519.png
# Saved frame_0520.png
# Saved frame_0521.png
# Saved frame_0522.png
# Saved frame_0523.png
# Saved frame_0524.png
# Saved frame_0525.png
# Saved frame_0526.png
# Saved frame_0527.png
# Saved frame_0528.png
# Saved frame_0529.png
# Saved frame_0530.png
# Saved frame_0531.png
# Saved frame_0532.png
# Saved frame_0533.png
# Saved frame_0534.png
# Saved frame_0535.png
# Saved frame_0536.png
# Saved frame_0537.png
# Saved frame_0538.png
# Saved frame_0539.png
# Saved frame_0540.png
# Saved frame_0541.png
# Saved frame_0542.png
# Saved frame_0543.png
# Saved frame_0544.png
# Saved frame_0545.png
# Saved frame_0546.png
# Saved frame_0547.png
# Saved frame_0548.png
# Saved frame_0549.png
# Saved frame_0550.png
# Saved frame_0551.png
# Saved frame_0552.png
# Saved frame_0553.png
# Saved frame_0554.png
# Saved frame_0555.png
# Saved frame_0556.png
# Saved frame_0557.png
# Saved frame_0558.png
# Saved frame_0559.png
# Saved frame_0560.png
# Saved frame_0561.png
# Saved frame_0562.png
# Saved frame_0563.png
# Saved frame_0564.png
# Saved frame_0565.png
# Saved frame_0566.png
# Saved frame_0567.png
# Saved frame_0568.png
# Saved frame_0569.png
# Saved frame_0570.png
# Saved frame_0571.png
# Saved frame_0572.png
# Saved frame_0573.png
# Saved frame_0574.png
# Saved frame_0575.png
# Saved frame_0576.png
# Saved frame_0577.png
# Saved frame_0578.png
# Saved frame_0579.png
# Saved frame_0580.png
# Saved frame_0581.png
# Saved frame_0582.png
# Saved frame_0583.png
# Saved frame_0584.png
# Saved frame_0585.png
# Saved frame_0586.png
# Saved frame_0587.png
# Saved frame_0588.png
# Saved frame_0589.png
# Saved frame_0590.png
# Saved frame_0591.png
# Saved frame_0592.png
# Saved frame_0593.png
# Saved frame_0594.png
# Saved frame_0595.png
# Saved frame_0596.png
# Saved frame_0597.png
# Saved frame_0598.png
# Saved frame_0599.png
# Saved frame_0600.png
# Saved frame_0601.png
# Saved frame_0602.png
# Saved frame_0603.png
# Saved frame_0604.png
# Saved frame_0605.png
# Saved frame_0606.png
# Saved frame_0607.png
# Saved frame_0608.png
# Saved frame_0609.png
# Saved frame_0610.png
# Saved frame_0611.png
# Saved frame_0612.png
# Saved frame_0613.png
# Saved frame_0614.png
# Saved frame_0615.png
# Saved frame_0616.png
# Saved frame_0617.png
# Saved frame_0618.png
# Saved frame_0619.png
# Saved frame_0620.png
# Saved frame_0621.png
# Saved frame_0622.png
# Saved frame_0623.png
# Saved frame_0624.png
# Saved frame_0625.png
# Saved frame_0626.png
# Saved frame_0627.png
# Saved frame_0628.png
# Saved frame_0629.png
# Saved frame_0630.png
# Saved frame_0631.png
# Saved frame_0632.png
# Saved frame_0633.png
# Saved frame_0634.png
# Saved frame_0635.png
# Saved frame_0636.png
# Saved frame_0637.png
# Saved frame_0638.png
# Saved frame_0639.png
# Saved frame_0640.png
# Saved frame_0641.png
# Saved frame_0642.png
# Saved frame_0643.png
# Saved frame_0644.png
# Saved frame_0645.png
# Saved frame_0646.png
# Saved frame_0647.png
# Saved frame_0648.png
# Saved frame_0649.png
# Saved frame_0650.png
# Saved frame_0651.png
# Saved frame_0652.png
# Saved frame_0653.png
# Saved frame_0654.png
# Saved frame_0655.png
# Saved frame_0656.png
# Saved frame_0657.png
# Saved frame_0658.png
# Saved frame_0659.png
# Saved frame_0660.png
# Saved frame_0661.png
# Saved frame_0662.png
# Saved frame_0663.png
# Saved frame_0664.png
# Saved frame_0665.png
# Saved frame_0666.png
# Saved frame_0667.png
# Saved frame_0668.png
# Saved frame_0669.png
# Saved frame_0670.png
# Saved frame_0671.png
# Saved frame_0672.png
# Saved frame_0673.png
# Saved frame_0674.png
# Saved frame_0675.png
# Saved frame_0676.png
# Saved frame_0677.png
# Saved frame_0678.png
# Saved frame_0679.png
# Saved frame_0680.png
# Saved frame_0681.png
# Saved frame_0682.png
# Saved frame_0683.png
# Saved frame_0684.png
# Saved frame_0685.png
# Saved frame_0686.png
# Saved frame_0687.png
# Saved frame_0688.png
# Saved frame_0689.png
# Saved frame_0690.png
# Saved frame_0691.png
# Saved frame_0692.png
# Saved frame_0693.png
# Saved frame_0694.png
# Saved frame_0695.png
# Saved frame_0696.png
# Saved frame_0697.png
# Saved frame_0698.png
# Saved frame_0699.png
# Saved frame_0700.png
# Saved frame_0701.png
# Saved frame_0702.png
# Saved frame_0703.png
# Saved frame_0704.png
# Saved frame_0705.png
# Saved frame_0706.png
# Saved frame_0707.png
# Saved frame_0708.png
# Saved frame_0709.png
# Saved frame_0710.png
# Saved frame_0711.png
# Saved frame_0712.png
# Saved frame_0713.png
# Saved frame_0714.png
# Saved frame_0715.png
# Saved frame_0716.png
# Saved frame_0717.png
# Saved frame_0718.png
# Saved frame_0719.png
# Saved frame_0720.png
# Saved frame_0721.png
# Saved frame_0722.png
# Saved frame_0723.png
# Saved frame_0724.png
# Saved frame_0725.png
# Saved frame_0726.png
# Saved frame_0727.png
# Saved frame_0728.png
# Saved frame_0729.png
# Saved frame_0730.png
# Saved frame_0731.png
# Saved frame_0732.png
# Saved frame_0733.png
# Saved frame_0734.png
# Saved frame_0735.png
# Saved frame_0736.png
# Saved frame_0737.png
# Saved frame_0738.png
# Saved frame_0739.png
# Saved frame_0740.png
# Saved frame_0741.png
# Saved frame_0742.png
# Saved frame_0743.png
# Saved frame_0744.png
# Saved frame_0745.png
# Saved frame_0746.png
# Saved frame_0747.png
# Saved frame_0748.png
# Saved frame_0749.png
# Saved frame_0750.png
# Saved frame_0751.png
# Saved frame_0752.png
# Saved frame_0753.png
# Saved frame_0754.png
# Saved frame_0755.png
# Saved frame_0756.png
# Saved frame_0757.png
# Saved frame_0758.png
# Saved frame_0759.png
# Saved frame_0760.png
# Saved frame_0761.png
# Saved frame_0762.png
# Saved frame_0763.png
# Saved frame_0764.png
# Saved frame_0765.png
# Saved frame_0766.png
# Saved frame_0767.png
# Saved frame_0768.png
# Saved frame_0769.png
# Saved frame_0770.png
# Saved frame_0771.png
# Saved frame_0772.png
# Saved frame_0773.png
# Saved frame_0774.png
# Saved frame_0775.png
# Saved frame_0776.png
# Saved frame_0777.png
# Saved frame_0778.png
# Saved frame_0779.png
# Saved frame_0780.png
# Saved frame_0781.png
# Saved frame_0782.png
# Saved frame_0783.png
# Saved frame_0784.png
# Saved frame_0785.png
# Saved frame_0786.png
# Saved frame_0787.png
# Saved frame_0788.png
# Saved frame_0789.png
# Saved frame_0790.png
# Saved frame_0791.png
# Saved frame_0792.png
# Saved frame_0793.png
# Saved frame_0794.png
# Saved frame_0795.png
# Saved frame_0796.png
# Saved frame_0797.png
# Saved frame_0798.png
# Saved frame_0799.png
# Saved frame_0800.png
# Saved frame_0801.png
# Saved frame_0802.png
# Saved frame_0803.png
# Saved frame_0804.png
# Saved frame_0805.png
# Saved frame_0806.png
# Saved frame_0807.png
# Saved frame_0808.png
# Saved frame_0809.png
# Saved frame_0810.png
# Saved frame_0811.png
# Saved frame_0812.png
# Saved frame_0813.png
# Saved frame_0814.png
# Saved frame_0815.png
# Saved frame_0816.png
# Saved frame_0817.png
# Saved frame_0818.png
# Saved frame_0819.png
# Saved frame_0820.png
# Saved frame_0821.png
# Saved frame_0822.png
# Saved frame_0823.png
# Saved frame_0824.png
# Saved frame_0825.png
# Saved frame_0826.png
# Saved frame_0827.png
# Saved frame_0828.png
# Saved frame_0829.png
# Saved frame_0830.png
# Saved frame_0831.png
# Saved frame_0832.png
# Saved frame_0833.png
# Saved frame_0834.png
# Saved frame_0835.png
# Saved frame_0836.png
# Saved frame_0837.png
# Saved frame_0838.png
# Saved frame_0839.png
# Saved frame_0840.png
# Saved frame_0841.png
# Saved frame_0842.png
# Saved frame_0843.png
# Saved frame_0844.png
# Saved frame_0845.png
# Saved frame_0846.png
# Saved frame_0847.png
# Saved frame_0848.png
# Saved frame_0849.png
# Saved frame_0850.png
# Saved frame_0851.png
# Saved frame_0852.png
# Saved frame_0853.png
# Saved frame_0854.png
# Saved frame_0855.png
# Saved frame_0856.png
# Saved frame_0857.png
# Saved frame_0858.png
# Saved frame_0859.png
# Saved frame_0860.png
# Saved frame_0861.png
# Saved frame_0862.png
# Saved frame_0863.png
# Saved frame_0864.png
# Saved frame_0865.png
# Saved frame_0866.png
# Saved frame_0867.png
# Saved frame_0868.png
# Saved frame_0869.png
# Saved frame_0870.png
# Saved frame_0871.png
# Saved frame_0872.png
# Saved frame_0873.png
# Saved frame_0874.png
# Saved frame_0875.png
# Saved frame_0876.png
# Saved frame_0877.png
# Saved frame_0878.png
# Saved frame_0879.png
# Saved frame_0880.png
# Saved frame_0881.png
# Saved frame_0882.png
# Saved frame_0883.png
# Saved frame_0884.png
# Saved frame_0885.png
# Saved frame_0886.png
# Saved frame_0887.png
# Saved frame_0888.png
# Saved frame_0889.png
# Saved frame_0890.png
# Saved frame_0891.png
# Saved frame_0892.png
# Saved frame_0893.png
# Saved frame_0894.png
# Saved frame_0895.png
# Saved frame_0896.png
# Saved frame_0897.png
# Saved frame_0898.png
# Saved frame_0899.png
# Saved frame_0900.png
# Saved frame_0901.png
# Saved frame_0902.png
# Saved frame_0903.png
# Saved frame_0904.png
# Saved frame_0905.png
# Saved frame_0906.png
# Saved frame_0907.png
# Saved frame_0908.png
# Saved frame_0909.png
# Saved frame_0910.png
# Saved frame_0911.png
# Saved frame_0912.png
# Saved frame_0913.png
# Saved frame_0914.png
# Saved frame_0915.png
# Saved frame_0916.png
# Saved frame_0917.png
# Saved frame_0918.png
# Saved frame_0919.png
# Saved frame_0920.png
# Saved frame_0921.png
# Saved frame_0922.png
# Saved frame_0923.png
# Saved frame_0924.png
# Saved frame_0925.png
# Saved frame_0926.png
# Saved frame_0927.png
# Saved frame_0928.png
# Saved frame_0929.png
# Saved frame_0930.png
# Saved frame_0931.png
# Saved frame_0932.png
# Saved frame_0933.png
# Saved frame_0934.png
# Saved frame_0935.png
# Saved frame_0936.png
# Saved frame_0937.png
# Saved frame_0938.png
# Saved frame_0939.png
# Saved frame_0940.png
# Saved frame_0941.png
# Saved frame_0942.png
# Saved frame_0943.png
# Saved frame_0944.png
# Saved frame_0945.png
# Saved frame_0946.png
# Saved frame_0947.png
# Saved frame_0948.png
# Saved frame_0949.png
# Saved frame_0950.png
# Saved frame_0951.png
# Saved frame_0952.png
# Saved frame_0953.png
# Saved frame_0954.png
# Saved frame_0955.png
# Saved frame_0956.png
# Saved frame_0957.png
# Saved frame_0958.png
# Saved frame_0959.png
# Saved frame_0960.png
# Saved frame_0961.png
# Saved frame_0962.png
# Saved frame_0963.png
# Saved frame_0964.png
# Saved frame_0965.png
# Saved frame_0966.png
# Saved frame_0967.png
# Saved frame_0968.png
# Saved frame_0969.png
# Saved frame_0970.png
# Saved frame_0971.png
# Saved frame_0972.png
# Saved frame_0973.png
# Saved frame_0974.png
# Saved frame_0975.png
# Saved frame_0976.png
# Saved frame_0977.png
# Saved frame_0978.png
# Saved frame_0979.png
# Saved frame_0980.png
# Saved frame_0981.png
# Saved frame_0982.png
# Saved frame_0983.png
# Saved frame_0984.png
# Saved frame_0985.png
# Saved frame_0986.png
# Saved frame_0987.png
# Saved frame_0988.png
# Saved frame_0989.png
# Saved frame_0990.png
# Saved frame_0991.png
# Saved frame_0992.png
# Saved frame_0993.png
# Saved frame_0994.png
# Saved frame_0995.png
# Saved frame_0996.png
# Saved frame_0997.png
# Saved frame_0998.png
# Saved frame_0999.png
# Saved frame_1000.png
# Saved frame_1001.png
# Saved frame_1002.png
# Saved frame_1003.png
# Saved frame_1004.png
# Saved frame_1005.png
# Saved frame_1006.png
# Saved frame_1007.png
# Saved frame_1008.png
# Saved frame_1009.png
# Saved frame_1010.png
# Saved frame_1011.png
# Saved frame_1012.png
# Saved frame_1013.png
# Saved frame_1014.png
# Saved frame_1015.png
# Saved frame_1016.png
# Saved frame_1017.png
# Saved frame_1018.png
# Saved frame_1019.png
# Saved frame_1020.png
# Saved frame_1021.png
# Saved frame_1022.png
# Saved frame_1023.png
# Saved frame_1024.png
# Saved frame_1025.png
# Saved frame_1026.png
# Saved frame_1027.png
# Saved frame_1028.png
# Saved frame_1029.png
# Saved frame_1030.png
# Saved frame_1031.png
# Saved frame_1032.png
# Saved frame_1033.png
# Saved frame_1034.png
# Saved frame_1035.png
# Saved frame_1036.png
# Saved frame_1037.png
# Saved frame_1038.png
# Saved frame_1039.png
# Saved frame_1040.png
# Saved frame_1041.png
# Saved frame_1042.png
# Saved frame_1043.png
# Saved frame_1044.png
# Saved frame_1045.png
# Saved frame_1046.png
# Saved frame_1047.png
# Saved frame_1048.png
# Saved frame_1049.png
# Saved frame_1050.png
# Saved frame_1051.png
# Saved frame_1052.png
# Saved frame_1053.png
# Saved frame_1054.png
# Saved frame_1055.png
# Saved frame_1056.png
# Saved frame_1057.png
# Saved frame_1058.png
# Saved frame_1059.png
# Saved frame_1060.png
# Saved frame_1061.png
# Saved frame_1062.png
# Saved frame_1063.png
# Saved frame_1064.png
# Saved frame_1065.png
# Saved frame_1066.png
# Saved frame_1067.png
# Saved frame_1068.png
# Saved frame_1069.png
# Saved frame_1070.png
# Saved frame_1071.png
# Saved frame_1072.png
# Saved frame_1073.png
# Saved frame_1074.png
# Saved frame_1075.png
# Saved frame_1076.png
# Saved frame_1077.png
# Saved frame_1078.png
# Saved frame_1079.png
# Saved frame_1080.png
# Saved frame_1081.png
# Saved frame_1082.png
# Saved frame_1083.png
# Saved frame_1084.png
# Saved frame_1085.png
# Saved frame_1086.png
# Saved frame_1087.png
# Saved frame_1088.png
# Saved frame_1089.png
# Saved frame_1090.png
# Saved frame_1091.png
# Saved frame_1092.png
# Saved frame_1093.png
# Saved frame_1094.png
# Saved frame_1095.png
# Saved frame_1096.png
# Saved frame_1097.png
# Saved frame_1098.png
# Saved frame_1099.png
# Saved frame_1100.png
# Saved frame_1101.png
# Saved frame_1102.png
# Saved frame_1103.png
# Saved frame_1104.png
# Saved frame_1105.png
# Saved frame_1106.png
# Saved frame_1107.png
# Saved frame_1108.png
# Saved frame_1109.png
# Saved frame_1110.png
# Saved frame_1111.png
# Saved frame_1112.png
# Saved frame_1113.png
# Saved frame_1114.png
# Saved frame_1115.png
# Saved frame_1116.png
# Saved frame_1117.png
# Saved frame_1118.png
# Saved frame_1119.png
# Saved frame_1120.png
# Saved frame_1121.png
# Saved frame_1122.png
# Saved frame_1123.png
# Saved frame_1124.png
# Saved frame_1125.png
# Saved frame_1126.png
# Saved frame_1127.png
# Saved frame_1128.png
# Saved frame_1129.png
# Saved frame_1130.png
# Saved frame_1131.png
# Saved frame_1132.png
# Saved frame_1133.png
# Saved frame_1134.png
# Saved frame_1135.png
# Saved frame_1136.png
# Saved frame_1137.png
# Saved frame_1138.png
# Saved frame_1139.png
# Saved frame_1140.png
# Saved frame_1141.png
# Saved frame_1142.png
# Saved frame_1143.png
# Saved frame_1144.png
# Saved frame_1145.png
# Saved frame_1146.png
# Saved frame_1147.png
# Saved frame_1148.png
# Saved frame_1149.png
# Saved frame_1150.png
# Saved frame_1151.png
# Saved frame_1152.png
# Saved frame_1153.png
# Saved frame_1154.png
# Saved frame_1155.png
# Saved frame_1156.png
# Saved frame_1157.png
# Saved frame_1158.png
# Saved frame_1159.png
# Saved frame_1160.png
# Saved frame_1161.png
# Saved frame_1162.png
# Saved frame_1163.png
# Saved frame_1164.png
# Saved frame_1165.png
# Saved frame_1166.png
# Saved frame_1167.png
# Saved frame_1168.png
# Saved frame_1169.png
# Saved frame_1170.png
# Saved frame_1171.png
# Saved frame_1172.png
# Saved frame_1173.png
# Saved frame_1174.png
# Saved frame_1175.png
# Saved frame_1176.png
# Saved frame_1177.png
# Saved frame_1178.png
# Saved frame_1179.png
# Saved frame_1180.png
# Saved frame_1181.png
# Saved frame_1182.png
# Saved frame_1183.png
# Saved frame_1184.png
# Saved frame_1185.png
# Saved frame_1186.png
# Saved frame_1187.png
# Saved frame_1188.png
# Saved frame_1189.png
# Saved frame_1190.png
# Saved frame_1191.png
# Saved frame_1192.png
# Saved frame_1193.png
# Saved frame_1194.png
# Saved frame_1195.png
# Saved frame_1196.png
# Saved frame_1197.png
# Saved frame_1198.png
# Saved frame_1199.png
# Saved frame_1200.png
# Saved frame_1201.png
# Saved frame_1202.png
# Saved frame_1203.png
# Saved frame_1204.png
# Saved frame_1205.png
# Saved frame_1206.png
# Saved frame_1207.png
# Saved frame_1208.png
# Saved frame_1209.png
# Saved frame_1210.png
# Saved frame_1211.png
# Saved frame_1212.png
# Saved frame_1213.png
# Saved frame_1214.png
# Saved frame_1215.png
# Saved frame_1216.png
# Saved frame_1217.png
# Saved frame_1218.png
# Saved frame_1219.png
# Saved frame_1220.png
# Saved frame_1221.png
# Saved frame_1222.png
# Saved frame_1223.png
# Saved frame_1224.png
# Saved frame_1225.png
# Saved frame_1226.png
# Saved frame_1227.png
# Saved frame_1228.png
# Saved frame_1229.png
# Saved frame_1230.png
# Saved frame_1231.png
# Saved frame_1232.png
# Saved frame_1233.png
# Saved frame_1234.png
# Saved frame_1235.png
# Saved frame_1236.png
# Saved frame_1237.png
# Saved frame_1238.png
# Saved frame_1239.png
# Saved frame_1240.png
# Saved frame_1241.png
# Saved frame_1242.png
# Saved frame_1243.png
# Saved frame_1244.png
# Saved frame_1245.png
# Saved frame_1246.png
# Saved frame_1247.png
# Saved frame_1248.png
# Saved frame_1249.png
# Saved frame_1250.png
# Saved frame_1251.png
# Saved frame_1252.png
# Saved frame_1253.png
# Saved frame_1254.png
# Saved frame_1255.png
# Saved frame_1256.png
# Saved frame_1257.png
# Saved frame_1258.png
# Saved frame_1259.png
# Saved frame_1260.png
# Saved frame_1261.png
# Saved frame_1262.png
# Saved frame_1263.png
# Saved frame_1264.png
# Saved frame_1265.png
# Saved frame_1266.png
# Saved frame_1267.png
# Saved frame_1268.png
# Saved frame_1269.png
# Saved frame_1270.png
# Saved frame_1271.png
# Saved frame_1272.png
# Saved frame_1273.png
# Saved frame_1274.png
# Saved frame_1275.png
# Saved frame_1276.png
# Saved frame_1277.png
# Saved frame_1278.png
# Saved frame_1279.png
# Saved frame_1280.png
# Saved frame_1281.png
# Saved frame_1282.png
# Saved frame_1283.png
# Saved frame_1284.png
# Saved frame_1285.png
# Saved frame_1286.png
# Saved frame_1287.png
# Saved frame_1288.png
# Saved frame_1289.png
# Saved frame_1290.png
# Saved frame_1291.png
# Saved frame_1292.png
# Saved frame_1293.png
# Saved frame_1294.png
# Saved frame_1295.png
# Saved frame_1296.png
# Saved frame_1297.png
# Saved frame_1298.png
# Saved frame_1299.png
# Saved frame_1300.png
# Saved frame_1301.png
# Saved frame_1302.png
# Saved frame_1303.png
# Saved frame_1304.png
# Saved frame_1305.png
# Saved frame_1306.png
# Saved frame_1307.png
# Saved frame_1308.png
# Saved frame_1309.png
# Saved frame_1310.png
# Saved frame_1311.png
# Saved frame_1312.png
# Saved frame_1313.png
# Saved frame_1314.png
# Saved frame_1315.png
# Saved frame_1316.png
# Saved frame_1317.png
# Saved frame_1318.png
# Saved frame_1319.png
# Saved frame_1320.png
# Saved frame_1321.png
# Saved frame_1322.png
# Saved frame_1323.png
# Saved frame_1324.png
# Saved frame_1325.png
# Saved frame_1326.png
# Saved frame_1327.png
# Saved frame_1328.png
# Saved frame_1329.png
# Saved frame_1330.png
# Saved frame_1331.png
# Saved frame_1332.png
# Saved frame_1333.png
# Saved frame_1334.png
# Saved frame_1335.png
# Saved frame_1336.png
# Saved frame_1337.png
# Saved frame_1338.png
# Saved frame_1339.png
# Saved frame_1340.png
# Saved frame_1341.png
# Saved frame_1342.png
# Saved frame_1343.png
# Saved frame_1344.png
# Saved frame_1345.png
# Saved frame_1346.png
# Saved frame_1347.png
# Saved frame_1348.png
# Saved frame_1349.png
# Saved frame_1350.png
# Saved frame_1351.png
# Saved frame_1352.png
# Saved frame_1353.png
# Saved frame_1354.png
# Saved frame_1355.png
# Saved frame_1356.png
# Saved frame_1357.png
# Saved frame_1358.png
# Saved frame_1359.png
# Saved frame_1360.png
# Saved frame_1361.png
# Saved frame_1362.png
# Saved frame_1363.png
# Saved frame_1364.png
# Saved frame_1365.png
# Saved frame_1366.png
# Saved frame_1367.png
# Saved frame_1368.png
# Saved frame_1369.png
# Saved frame_1370.png
# Saved frame_1371.png
# Saved frame_1372.png
# Saved frame_1373.png
# Saved frame_1374.png
# Saved frame_1375.png
# Saved frame_1376.png
# Saved frame_1377.png
# Saved frame_1378.png
# Saved frame_1379.png
# Creating video...
# ffmpeg version 7.1.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 18.1.8
#   configuration: --prefix=/Users/bmapes/.local/share/mamba/envs/hk25 --cc=arm64-apple-darwin20.0.0-clang --cxx=arm64-apple-darwin20.0.0-clang++ --nm=arm64-apple-darwin20.0.0-nm --ar=arm64-apple-darwin20.0.0-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1746479731466/_build_env/bin/x86_64-apple-darwin13.4.0-clang --enable-neon --disable-gnutls --enable-libvpx --enable-libass --enable-pthreads --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1746479731466/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.101 / 61. 19.101
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, image2, from '/Users/bmapes/Box/Sky_Symphony_Box/ERNESTO12/MERGEDIR_BOXES/frames/frame_%04d.png':
#   Duration: 00:03:50.00, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgba(pc, gbr/unknown/unknown), 1500x900 [SAR 5906:5906 DAR 5:3], 6 fps, 6 tbr, 6 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x15c0057c0] using SAR=1/1
# [libx264 @ 0x15c0057c0] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x15c0057c0] profile High, level 4.0, 4:2:0, 8-bit
# [libx264 @ 0x15c0057c0] 264 - core 164 r3095 baee400 - H.264/MPEG-4 AVC codec - Copyleft 2003-2022 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=6 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/Users/bmapes/Box/Sky_Symphony_Box/ERNESTO12/MERGEDIR_BOXES/enhanced_ir.mp4':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 1500x900 [SAR 1:1 DAR 5:3], q=2-31, 6 fps, 12288 tbn
#       Metadata:
#         encoder         : Lavc61.19.101 libx264
#       Side data:
#         cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame= 1363 fps= 38 q=23.0 size=  252416KiB time=00:03:46.83 bitrate=9115.9kbits/s speed=6.39x
# ✅ Video saved as /Users/bmapes/Box/Sky_Symphony_Box/ERNESTO12/MERGEDIR_BOXES/enhanced_ir.mp4
# [out#0/mp4 @ 0x600003764000] video:255876KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.007027%
# frame= 1380 fps= 39 q=-1.0 Lsize=  255894KiB time=00:03:49.66 bitrate=9127.5kbits/s speed=6.42x
# [libx264 @ 0x15c0057c0] frame I:12    Avg QP:18.77  size:271533
# [libx264 @ 0x15c0057c0] frame P:455   Avg QP:24.29  size:196204
# [libx264 @ 0x15c0057c0] frame B:913   Avg QP:25.65  size:185636
# [libx264 @ 0x15c0057c0] consecutive B-frames: 11.5%  0.6%  0.7% 87.2%
# [libx264 @ 0x15c0057c0] mb I  I16..4: 14.1% 33.5% 52.4%
# [libx264 @ 0x15c0057c0] mb P  I16..4:  1.6% 19.4% 33.9%  P16..4:  4.3%  4.4%  3.2%  0.0%  0.0%    skip:33.2%
# [libx264 @ 0x15c0057c0] mb B  I16..4:  0.7%  6.6% 26.1%  B16..8: 10.7% 11.3%  7.7%  direct: 4.5%  skip:32.3%  L0:32.6% L1:30.5% BI:36.8%
# [libx264 @ 0x15c0057c0] 8x8 transform intra:27.0% inter:29.4%
# [libx264 @ 0x15c0057c0] coded y,uvDC,uvAC intra: 94.8% 31.2% 30.1% inter: 35.2% 7.0% 6.9%
# [libx264 @ 0x15c0057c0] i16 v,h,dc,p: 40% 20% 24% 16%
# [libx264 @ 0x15c0057c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 11% 13% 14%  8% 10%  9% 12%  9% 14%
# [libx264 @ 0x15c0057c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 12% 15% 16%  9% 10%  8% 10%  8% 12%
# [libx264 @ 0x15c0057c0] i8c dc,h,v,p: 81%  9%  7%  3%
# [libx264 @ 0x15c0057c0] Weighted P-Frames: Y:0.4% UV:0.0%
# [libx264 @ 0x15c0057c0] ref P L0: 53.1% 16.1% 20.0% 10.8%  0.0%
# [libx264 @ 0x15c0057c0] ref B L0: 89.9%  7.7%  2.4%
# [libx264 @ 0x15c0057c0] ref B L1: 96.1%  3.9%
# [libx264 @ 0x15c0057c0] kb/s:9113.62
